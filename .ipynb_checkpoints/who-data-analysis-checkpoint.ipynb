# %% [markdown]
# ## Name of the Student: Yash Kamdar
# ## E-mail: ykamdar@scu.edu
#
# ## Link: https://github.com/yash9516/Assignment-Datasets/blob/master/WHO.csv

# %% [markdown]
# ### About dataset: A compilation of a set of social, economic, health, and political indicators using data from the World Health Organization and partner organizations.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap

# %matplotlib inline

# %% [markdown]
# #### Loading the dataset

# %%
df = pd.read_csv("../input/WHO.csv")
pd.set_option('display.max_rows', 500) #Default Maximum rows to be displayed is set to 500
pd.set_option('display.max_columns',500) #Default Maximum columns to be displayed is set to 500
df.head()
# Out:
#        Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0  Afghanistan          1          1                          151.0
# 1      Albania          2          2                           27.0
# 2      Algeria          3          3                            6.0
# 3      Andorra          4          2                            NaN
# 4       Angola          5          3                          146.0
#
#    Adult literacy rate (%)  \
# 0                     28.0
# 1                     98.7
# 2                     69.9
# 3                      NaN
# 4                     67.4
#
#    Gross national income per capita (PPP international $)  \
# 0                                                NaN
# 1                                             6000.0
# 2                                             5940.0
# 3                                                NaN
# 4                                             3890.0
#
#    Net primary school enrolment ratio female (%)  \
# ...

# %% [markdown]
# > Checking the dimension of the dataset

# %%
df.shape
# Out:
# (202, 358)

# %% [markdown]
# > Check the name of Columns

# %%
df.columns
# Out:
# Index(['Country', 'CountryID', 'Continent', 'Adolescent fertility rate (%)',
#        'Adult literacy rate (%)',
#        'Gross national income per capita (PPP international $)',
#        'Net primary school enrolment ratio female (%)',
#        'Net primary school enrolment ratio male (%)',
#        'Population (in thousands) total', 'Population annual growth rate (%)',
#        ...
#        'Total_CO2_emissions', 'Total_income', 'Total_reserves',
#        'Trade_balance_goods_and_services', 'Under_five_mortality_from_CME',
#        'Under_five_mortality_from_IHME', 'Under_five_mortality_rate',
#        'Urban_population', 'Urban_population_growth',
#        'Urban_population_pct_of_total'],
#       dtype='object', length=358)

# %% [markdown]
# > Set column 'CountryID' as the default index and drop its as column

# %%
df.set_index('Country',drop=True, inplace=True)

# %% [markdown]
# > Get overview of dataset

# %%
df.head()
# Out:
#              CountryID  Continent  Adolescent fertility rate (%)  \
# Country
# Afghanistan          1          1                          151.0
# Albania              2          2                           27.0
# Algeria              3          3                            6.0
# Andorra              4          2                            NaN
# Angola               5          3                          146.0
#
#              Adult literacy rate (%)  \
# Country
# Afghanistan                     28.0
# Albania                         98.7
# Algeria                         69.9
# Andorra                          NaN
# Angola                          67.4
#
#              Gross national income per capita (PPP international $)  \
# Country
# Afghanistan                                                NaN
# Albania                                                 6000.0
# Algeria                                                 5940.0
# ...

# %% [markdown]
# > We notice that some of the column names contains expression "&lt" and "&gt" which atually implies "<" and ">". So we are replacing "&lt" with "<" and "&gt" with ">".

# %%
df.columns = df.columns.str.replace("&lt;", "<")
df.columns = df.columns.str.replace("&gt;", ">")
df.head()
# Out:
#              CountryID  Continent  Adolescent fertility rate (%)  \
# Country
# Afghanistan          1          1                          151.0
# Albania              2          2                           27.0
# Algeria              3          3                            6.0
# Andorra              4          2                            NaN
# Angola               5          3                          146.0
#
#              Adult literacy rate (%)  \
# Country
# Afghanistan                     28.0
# Albania                         98.7
# Algeria                         69.9
# Andorra                          NaN
# Angola                          67.4
#
#              Gross national income per capita (PPP international $)  \
# Country
# Afghanistan                                                NaN
# Albania                                                 6000.0
# Algeria                                                 5940.0
# ...

# %% [markdown]
# ## Finding 1: Does high adult literacy rate imply more number of patents?

# %% [markdown]
# > Getting average of world population

# %%
average_population=df['Population_total'].mean()

# %% [markdown]
# > Get names of those countries whose population is more than world's average and sort them by their Total Population

# %%
Adult_literacy_rate_top_25=df[df['Population_total']>average_population].sort_values(by='Adult literacy rate (%)',ascending=False).head(25)
series_Adult_literacy_rate_top_25=Adult_literacy_rate_top_25['Adult literacy rate (%)']
series_Adult_literacy_rate_top_25
# Out:
# Country
# Ukraine             99.4
# Italy               98.4
# Argentina           97.2
# Spain               97.2
# Colombia            92.8
# Thailand            92.6
# Philippines         92.6
# Mexico              91.6
# China               90.9
# Indonesia           90.4
# Vietnam             90.3
# Myanmar             89.9
# Brazil              88.6
# Turkey              87.4
# South Africa        82.4
# Tanzania            69.4
# Nigeria             69.0
# Congo, Dem. Rep.    67.2
# India               61.0
# Sudan               60.9
# Pakistan            49.9
# Bangladesh          47.5
# Ethiopia            35.9
# France               NaN
# Germany              NaN
# Name: Adult literacy rate (%), dtype: float64

# %% [markdown]
# > Get list of Top 10 countries with highest number of Patents granted

# %%
Patents_granted=df['Patents_granted']
Patents_granted_top_25=Patents_granted.sort_values(ascending=False).head(25)
print("Top 25 countries with highest number of Patents granted")
Patents_granted_top_25
# Out:
# Top 25 countries with highest number of Patents granted
# Country
# United States of America    167334.0
# Japan                       120018.0
# Germany                      61153.0
# France                       53415.0
# United Kingdom               52593.0
# Korea, Rep.                  45298.0
# Italy                        34899.0
# Netherlands                  27482.0
# Spain                        26626.0
# Sweden                       24546.0
# Switzerland                  21852.0
# China                        21473.0
# Belgium                      20785.0
# Austria                      20390.0
# Russia                       18114.0
# Denmark                      16469.0
# Australia                    14496.0
# Ireland                      14203.0
# Portugal                     13840.0
# Greece                       13235.0
# Canada                       12951.0
# Luxembourg                   12176.0
# Ukraine                      11670.0
# ...

# %% [markdown]
# ### Get those countries who are in the top 25 list of highest literacy rate and one's with top 25 highest patents files

# %% [markdown]
# ### Showed findings with the help of a table

# %% [markdown]
# > Merged both the above series with an inner join so as to get only those countries which are common in both series

# %%
series_literacyrate_patents = pd.merge(series_Adult_literacy_rate_top_25,Patents_granted_top_25, how="inner", on="Country")
series_literacyrate_patents.dropna() #Dropped rows with NaN values for either of the two columns
# Out:
#          Adult literacy rate (%)  Patents_granted
# Country
# Ukraine                     99.4          11670.0
# Italy                       98.4          34899.0
# Spain                       97.2          26626.0
# China                       90.9          21473.0

# %% [markdown]
# ## Conclusion:
# ### Out of the World's 25 most Literate countries, there are only 4 countries who appear on the list of the 25 countries with highest patents granted.
# ### Literacy does not imply high number of patents being granted.

# %% [markdown]
# ## Finding 2:
# ## Analyze the relation between countries with highest deaths due to liver cancer and countries with highest per capita alcohol consumption

# %% [markdown]
# > Find out Average per capita Alcohol Consumption

# %%
#Average of deaths by liver cancer
Average_of_per_capita_alcohol_consumption=df['Per capita recorded alcohol consumption (litres of pure alcohol) among adults (>=15 years)'].mean()
Average_of_per_capita_alcohol_consumption
print("Average  per capita Alcohol Consumption is: ", Average_of_per_capita_alcohol_consumption, "litres")
# Out:
# Average  per capita Alcohol Consumption is:  4.518555555555555 litres

# %% [markdown]
# > Created a new Column - "Deaths by Liver Cancer" whose values are sum of Male deaths by liver cancer and female deaths by liver cancer

# %%
df['Deaths by Liver Cancer']=df.Liver_cancer_number_of_male_deaths + df.Liver_cancer_number_of_female_deaths # Concat columns to get total deaths by liver cancer
df['Deaths by Liver Cancer']=df['Deaths by Liver Cancer'].fillna(0) #filling all nana values with 0
df_liver_cancer_analysis=df[['Per capita recorded alcohol consumption (litres of pure alcohol) among adults (>=15 years)','Deaths by Liver Cancer']].sort_values(by='Deaths by Liver Cancer',ascending=False).head(10)
df_liver_cancer_analysis
# Out:
#                           Per capita recorded alcohol consumption (litres of pure alcohol) among adults (>=15 years)  \
# Country
# China                                                                  5.20
# Japan                                                                  7.59
# Thailand                                                               5.59
# United States of America                                               8.61
# India                                                                  0.29
# Korea, Rep.                                                            7.87
# Indonesia                                                              0.09
# Italy                                                                  8.02
# Vietnam                                                                0.85
# Russia                                                                10.32
#
#                           Deaths by Liver Cancer
# Country
# ...

# %%
plt.figure(figsize=(16,9))
# figure ration 16:9
sns.set() # for style
sns.barplot(y=df_liver_cancer_analysis['Deaths by Liver Cancer'],x=df_liver_cancer_analysis['Per capita recorded alcohol consumption (litres of pure alcohol) among adults (>=15 years)'])

# %% [markdown]
# ## Conclusion:
# ### Out of 10 countries with highest deaths due to liver cancer, 7 countries are the one's whos Per capita consumption of Alcohol is more than that of World's average.

# %% [markdown]
# ## Finding 3: Considering a dataset of countries with  highest rate of adult literate female, is this rate consistent with rate of youth literate female? If yes then it means that all the female literate youths are getting converted to female literate adults.

# %%
df_female_literacy_analysis=df[['Literacy_rate_youth_female','Literacy_rate_adult_female']].sort_values(by="Literacy_rate_adult_female",ascending=False).head(10)
df_female_literacy_analysis
# Out:
#             Literacy_rate_youth_female  Literacy_rate_adult_female
# Country
# Cuba                             99.95                       99.79
# Estonia                          99.81                       99.76
# Latvia                           99.78                       99.71
# Lithuania                        99.74                       99.65
# Slovenia                         99.88                       99.64
# Belarus                          99.83                       99.42
# Kazakhstan                       99.87                       99.29
# Russia                           99.77                       99.23
# Tajikistan                       99.85                       99.22
# Ukraine                          99.83                       99.17

# %%
plt.figure(figsize=(16,9))
plt.scatter(x=df_female_literacy_analysis.index,y='Literacy_rate_youth_female', data=df_female_literacy_analysis)
plt.scatter(x=df_female_literacy_analysis.index,y='Literacy_rate_adult_female', data=df_female_literacy_analysis)
plt.legend(['Youth','Adult'], title="Female Literacy Rates")
plt.show()

# %% [markdown]
# ## Conclusion:
# ### We notice a pattern that all the 10 countries with highest female adult literacy rates, the female youth literacy rate is always higher.
# ### It implies that the all the female youths do not proceed for higher education.
